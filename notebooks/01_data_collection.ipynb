# %%
import pandas as pd
from pathlib import Path

# --- 1. Define Project Root ---
# Since the notebook is located inside the "notebooks/" folder, 
# we use .parent to navigate up one level to the project root.
current_dir = Path.cwd()
PROJECT_ROOT = current_dir.parent

# --- 2. Define Main Directories ---
DATA_DIR = PROJECT_ROOT / 'data'
FIG_DIR  = PROJECT_ROOT / 'figures'  # Useful for saving plots later

# --- 3. Define Data Sub-directories ---
# Processed Data Folder
PROCESSED_DIR = DATA_DIR / 'processed'

# Raw Data Folder and its sub-categories
RAW_DIR = DATA_DIR / 'raw'
RAW_ELECTIONS  = RAW_DIR / 'election_results'
RAW_MANIFESTOS = RAW_DIR / 'manifestos'
RAW_SOCIO      = RAW_DIR / 'socio-economic'
RAW_SPEECHES   = RAW_DIR / 'speeches'

# --- Verification (Optional: Prints paths to confirm connection) ---
print(f"Project Root detected: {PROJECT_ROOT}")
print(f"Processed data folder exists: {PROCESSED_DIR.exists()}")
print(f"Raw data folder exists: {RAW_DIR.exists()}")
# Out:
# Project Root detected: /Users/jessicabourdouxhe/Desktop/Master 1/Data/Projet /elections-nlp-project
# Processed data folder exists: True
# Raw data folder exists: True
